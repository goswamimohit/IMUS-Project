# %%
import pandas as pd
import seaborn as sns
sns.set(rc={'figure.figsize':(11.7,8.27)})

# %%
df = pd.read_csv('price_trend.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 713788 entries, 0 to 713787
# Data columns (total 6 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   category      713788 non-null  int64
#  1   manufacturer  713788 non-null  object
#  2   product       713788 non-null  object
#  3   qty           713788 non-null  int64
#  4   price         713788 non-null  float64
#  5   date          713788 non-null  object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 32.7+ MB

# %%
pric_01 = df.drop(['manufacturer', 'category','qty'], axis=1)

# %%
pric_01.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 713788 entries, 0 to 713787
# Data columns (total 3 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   product  713788 non-null  object
#  1   price    713788 non-null  float64
#  2   date     713788 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 16.3+ MB

# %%
kl = pric_01.loc[pric_01.groupby('product').date.idxmax(),:]

# %%
kl
# Out:
#                  product    price       date
# 454314           0-00496    59.62 2020-08-24
# 98638            0-00498    96.65 2020-08-17
# 494382  003-000884-01-OE   398.68 2020-08-24
# 403571             00385     1.80 2020-08-24
# 403585             00388     2.48 2020-08-24
# ...                  ...      ...        ...
# 454668  ZT62062-T01A100Z  4001.17 2020-08-24
# 543453  ZT62063-T010100Z  3797.41 2020-08-25
# 454670  ZT62063-T01A100Z  4140.69 2020-08-24
# 454671  ZT62063-T110100Z  4344.44 2020-08-24
# 455638          ZUCUBJCK    16.74 2020-08-24
#
# [30672 rows x 3 columns]

# %%
kl['price_max'] = kl['price']

# %%
kl
# Out:
#                  product    price       date   date_max  price_max
# 454314           0-00496    59.62 2020-08-24 2020-08-24      59.62
# 98638            0-00498    96.65 2020-08-17 2020-08-17      96.65
# 494382  003-000884-01-OE   398.68 2020-08-24 2020-08-24     398.68
# 403571             00385     1.80 2020-08-24 2020-08-24       1.80
# 403585             00388     2.48 2020-08-24 2020-08-24       2.48
# ...                  ...      ...        ...        ...        ...
# 454668  ZT62062-T01A100Z  4001.17 2020-08-24 2020-08-24    4001.17
# 543453  ZT62063-T010100Z  3797.41 2020-08-25 2020-08-25    3797.41
# 454670  ZT62063-T01A100Z  4140.69 2020-08-24 2020-08-24    4140.69
# 454671  ZT62063-T110100Z  4344.44 2020-08-24 2020-08-24    4344.44
# 455638          ZUCUBJCK    16.74 2020-08-24 2020-08-24      16.74
#
# [30672 rows x 5 columns]

# %%
km = pric_01.loc[pric_01.groupby('product').date.idxmin(),:]

# %%
km
# Out:
#                  product    price       date
# 98639            0-00496    59.62 2020-08-17
# 98638            0-00498    96.65 2020-08-17
# 138703  003-000884-01-OE   398.68 2020-08-17
# 47958              00385     1.80 2020-08-17
# 47972              00388     2.48 2020-08-17
# ...                  ...      ...        ...
# 99008   ZT62062-T01A100Z  4001.17 2020-08-17
# 99009   ZT62063-T010100Z  3797.41 2020-08-17
# 99010   ZT62063-T01A100Z  4140.69 2020-08-17
# 99011   ZT62063-T110100Z  4344.44 2020-08-17
# 99942           ZUCUBJCK    16.74 2020-08-17
#
# [30672 rows x 3 columns]

# %%
kl['price_min'] = km['price']

# %%
kn = kl.drop(['price_min', 'date_max','date','price'], axis=1)

# %%
kn
# Out:
#                  product  price_max
# 454314           0-00496      59.62
# 98638            0-00498      96.65
# 494382  003-000884-01-OE     398.68
# 403571             00385       1.80
# 403585             00388       2.48
# ...                  ...        ...
# 454668  ZT62062-T01A100Z    4001.17
# 543453  ZT62063-T010100Z    3797.41
# 454670  ZT62063-T01A100Z    4140.69
# 454671  ZT62063-T110100Z    4344.44
# 455638          ZUCUBJCK      16.74
#
# [30672 rows x 2 columns]

# %%
ko=km.drop(['date','price'],axis=1)

# %%
ko
# Out:
#                  product  price_min
# 98639            0-00496      59.62
# 98638            0-00498      96.65
# 138703  003-000884-01-OE     398.68
# 47958              00385       1.80
# 47972              00388       2.48
# ...                  ...        ...
# 99008   ZT62062-T01A100Z    4001.17
# 99009   ZT62063-T010100Z    3797.41
# 99010   ZT62063-T01A100Z    4140.69
# 99011   ZT62063-T110100Z    4344.44
# 99942           ZUCUBJCK      16.74
#
# [30672 rows x 2 columns]

# %%
ko['price_min'] = km['price']

# %%
ko
# Out:
#                  product  price_min
# 98639            0-00496      59.62
# 98638            0-00498      96.65
# 138703  003-000884-01-OE     398.68
# 47958              00385       1.80
# 47972              00388       2.48
# ...                  ...        ...
# 99008   ZT62062-T01A100Z    4001.17
# 99009   ZT62063-T010100Z    3797.41
# 99010   ZT62063-T01A100Z    4140.69
# 99011   ZT62063-T110100Z    4344.44
# 99942           ZUCUBJCK      16.74
#
# [30672 rows x 2 columns]

# %%
kn
# Out:
#                  product  price_max
# 454314           0-00496      59.62
# 98638            0-00498      96.65
# 494382  003-000884-01-OE     398.68
# 403571             00385       1.80
# 403585             00388       2.48
# ...                  ...        ...
# 454668  ZT62062-T01A100Z    4001.17
# 543453  ZT62063-T010100Z    3797.41
# 454670  ZT62063-T01A100Z    4140.69
# 454671  ZT62063-T110100Z    4344.44
# 455638          ZUCUBJCK      16.74
#
# [30672 rows x 2 columns]

# %%
ko.merge(kn[['product']])
# Out:
#                 product  price_min
# 0               0-00496      59.62
# 1               0-00498      96.65
# 2      003-000884-01-OE     398.68
# 3                 00385       1.80
# 4                 00388       2.48
# ...                 ...        ...
# 30667  ZT62062-T01A100Z    4001.17
# 30668  ZT62063-T010100Z    3797.41
# 30669  ZT62063-T01A100Z    4140.69
# 30670  ZT62063-T110100Z    4344.44
# 30671          ZUCUBJCK      16.74
#
# [30672 rows x 2 columns]

# %%
kn
# Out:
#                  product  price_max
# 454314           0-00496      59.62
# 98638            0-00498      96.65
# 494382  003-000884-01-OE     398.68
# 403571             00385       1.80
# 403585             00388       2.48
# ...                  ...        ...
# 454668  ZT62062-T01A100Z    4001.17
# 543453  ZT62063-T010100Z    3797.41
# 454670  ZT62063-T01A100Z    4140.69
# 454671  ZT62063-T110100Z    4344.44
# 455638          ZUCUBJCK      16.74
#
# [30672 rows x 2 columns]

# %%
ko
# Out:
#                  product  price_min
# 98639            0-00496      59.62
# 98638            0-00498      96.65
# 138703  003-000884-01-OE     398.68
# 47958              00385       1.80
# 47972              00388       2.48
# ...                  ...        ...
# 99008   ZT62062-T01A100Z    4001.17
# 99009   ZT62063-T010100Z    3797.41
# 99010   ZT62063-T01A100Z    4140.69
# 99011   ZT62063-T110100Z    4344.44
# 99942           ZUCUBJCK      16.74
#
# [30672 rows x 2 columns]

# %%
df_row = pd.concat([ko, kn])

# %%
df_row.head(50)
# Out:
#                  product  price_min  price_max
# 98639            0-00496      59.62        NaN
# 98638            0-00498      96.65        NaN
# 138703  003-000884-01-OE     398.68        NaN
# 47958              00385       1.80        NaN
# 47972              00388       2.48        NaN
# 47986              00392       1.20        NaN
# 48000              00394       1.80        NaN
# 48014              00397       2.48        NaN
# 48028              00398       3.79        NaN
# 48042              00401       1.28        NaN
# 48056              00403       1.80        NaN
# 48070              00409       6.65        NaN
# 48084              00420       1.28        NaN
# 48098              00436       2.78        NaN
# 48112              00448       2.22        NaN
# 48126              00463       1.35        NaN
# 91043              00477       6.65        NaN
# 48140              00496       1.69        NaN
# 95063              00497       1.80        NaN
# ...

# %%
df_row_index = df_row.set_index(['product']).sort_index()

# %%
df_row_index
# Out:
#                   price_min  price_max
# product
# 0-00496               59.62        NaN
# 0-00496                 NaN      59.62
# 0-00498               96.65        NaN
# 0-00498                 NaN      96.65
# 003-000884-01-OE     398.68        NaN
# ...                     ...        ...
# ZT62063-T01A100Z    4140.69        NaN
# ZT62063-T110100Z        NaN    4344.44
# ZT62063-T110100Z    4344.44        NaN
# ZUCUBJCK              16.74        NaN
# ZUCUBJCK                NaN      16.74
#
# [61344 rows x 2 columns]

# %%
df23 = pd.merge(ko, kn , on='product', how='outer')

# %%
df23
# Out:
#                 product  price_min  price_max
# 0               0-00496      59.62      59.62
# 1               0-00498      96.65      96.65
# 2      003-000884-01-OE     398.68     398.68
# 3                 00385       1.80       1.80
# 4                 00388       2.48       2.48
# ...                 ...        ...        ...
# 30667  ZT62062-T01A100Z    4001.17    4001.17
# 30668  ZT62063-T010100Z    3797.41    3797.41
# 30669  ZT62063-T01A100Z    4140.69    4140.69
# 30670  ZT62063-T110100Z    4344.44    4344.44
# 30671          ZUCUBJCK      16.74      16.74
#
# [30672 rows x 3 columns]

# %%
df23_row_index = df23.set_index(['product']).sort_index()

# %%
df23_row_index
# Out:
#                   price_min  price_max
# product
# 0-00496               59.62      59.62
# 0-00498               96.65      96.65
# 003-000884-01-OE     398.68     398.68
# 00385                  1.80       1.80
# 00388                  2.48       2.48
# ...                     ...        ...
# ZT62062-T01A100Z    4001.17    4001.17
# ZT62063-T010100Z    3797.41    3797.41
# ZT62063-T01A100Z    4140.69    4140.69
# ZT62063-T110100Z    4344.44    4344.44
# ZUCUBJCK              16.74      16.74
#
# [30672 rows x 2 columns]

# %%
df23['final_price']= df23['price_max']-df23['price_min']

# %%
df56 = df23.sort_values(by=['final_price'], ascending=True ,ignore_index=True)[0:10]

# %%
df56
# Out:
#             product  price_min  price_max  final_price
# 0       OFP2-100-QI   16999.12   12158.37     -4840.75
# 1     PS7551BDAFWOF    2622.91    1410.71     -1212.20
# 2       7KP95UT#ABA    1481.76     878.66      -603.10
# 3            JH395A   14558.86   14206.41      -352.45
# 4  100-100000053WOF    6897.43    6582.48      -314.95
# 5         LPE16000B     807.72     532.44      -275.28
# 6             XXC0C    2446.50    2202.05      -244.45
# 7         JKR-00001    2364.06    2127.66      -236.40
# 8             6Y3KF    2315.61    2084.31      -231.30
# 9            JH148A    7256.83    7063.40      -193.43

# %%
df57 = df23.sort_values(by=['final_price'], ascending=False ,ignore_index=True)[0:10]

# %%
df57
# Out:
#           product  price_min  price_max  final_price
# 0    0F31052-20PK    9432.75   10312.75       880.00
# 1    0F31051-20PK    9637.37   10517.37       880.00
# 2    0F29560-20PK    7951.19    8471.19       520.00
# 3    0F30146-20PK    7705.45    8225.45       520.00
# 4    0F30144-20PK    7746.57    8266.57       520.00
# 5    0B36406-20PK    5381.53    5741.53       360.00
# 6    0B36399-20PK    5177.92    5537.92       360.00
# 7  ESC8000 G4/10G    4015.10    4327.74       312.64
# 8   223-801-00000    5289.83    5577.32       287.49
# 9           XP0PY     907.38    1168.10       260.72

# %%
df23.head(50)
# Out:
#              product  price_min  price_max  final_price
# 0            0-00496      59.62      59.62         0.00
# 1            0-00498      96.65      96.65         0.00
# 2   003-000884-01-OE     398.68     398.68         0.00
# 3              00385       1.80       1.80         0.00
# 4              00388       2.48       2.48         0.00
# 5              00392       1.20       1.20         0.00
# 6              00394       1.80       1.80         0.00
# 7              00397       2.48       2.48         0.00
# 8              00398       3.79       3.79         0.00
# 9              00401       1.28       1.28         0.00
# 10             00403       1.80       1.80         0.00
# 11             00409       6.65       6.65         0.00
# 12             00420       1.28       1.28         0.00
# 13             00436       2.78       2.78         0.00
# 14             00448       2.22       2.22         0.00
# 15             00463       1.35       1.35         0.00
# ...

# %%
df24= df23.groupby(['final_price'])['product'].apply(lambda x: x.iloc[0:5])

# %%
df24.hist()
# Out:
# <AxesSubplot:>
# Error in callback <function flush_figures at 0x000001D21E275790> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\matplotlib_inline\backend_inline.py in flush_figures()
#     119         # ignore the tracking, just draw and close all figures
#     120         try:
# --> 121             return show(True)
#     122         except Exception as e:
#     123             # safely show traceback if in IPython, else raise
#
# ~\anaconda3\lib\site-packages\matplotlib_inline\backend_inline.py in show(close, block)
#      39     try:
#      40         for figure_manager in Gcf.get_all_fig_managers():
# ---> 41             display(
#      42                 figure_manager.canvas.figure,
#      43                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#
# ...

# %%
# Out:
# 0                 0-00496
# 1                 0-00498
# 2        003-000884-01-OE
# 3                   00385
# 4                   00388
#                ...
# 30636    ZT23043-T01200FZ
# 30644    ZT41046-T010000Z
# 30660    ZT51042-T210000Z
# 30663    ZT61042-T210100Z
# 30665    ZT61043-T01010GA
# Name: product, Length: 3071, dtype: object

# %%
df23.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30672 entries, 0 to 30671
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   product      30672 non-null  object
#  1   price_min    30672 non-null  float64
#  2   price_max    30672 non-null  float64
#  3   final_price  30672 non-null  float64
# dtypes: float64(3), object(1)
# memory usage: 2.2+ MB

# %%
df23.min()
# Out:
# product        0-00496
# price_min          0.0
# price_max          0.0
# final_price   -4840.75
# dtype: object

# %%
new = df23.filter(['product','final_price'], axis=1)

# %%
new.max()
# Out:
# product        ZUCUBJCK
# final_price       880.0
# dtype: object

# %%
new.min()
# Out:
# product        0-00496
# final_price   -4840.75
# dtype: object

# %%
new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30672 entries, 0 to 30671
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   product      30672 non-null  object
#  1   final_price  30672 non-null  float64
# dtypes: float64(1), object(1)
# memory usage: 1.7+ MB
